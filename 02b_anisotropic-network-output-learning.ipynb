# %%
"""
A network with an inhomogeneous weight structure (anisotropic network)

This example contains a reservoir network of 4500 neurons, distributed over 2 Loihi chips.
3600 neurons are excitatory and 900 neurons are inhibitory.
The neurons are locally connected with a gaussian distribution on a 2-dimensional grid of neurons.
Edges are connected to form a torus shape.
The gaussian distribution is shifted, where the shift direction is drawn by perlin noise.

The network activity is started with a short cue input and then maintained.
After some time the network activity is stopped using a snip.
The next trial is started with a short cue input again,
which is slightly different (noisy) than the one before.

Using linear regression, a function is trained from the trials (using all but the last).
Finally the spiking activity of the last trial is used to predict the function,
using the weights trained with the other trials.

The experiment is defined in pelenet/experiments/readoutanisotropic.py file.
An experiment can contain multiple network instances.
A log file, parameters, and plot figures are stored in the log folder for every run of the simulation.

NOTE: The main README file contains some more information about the structure of pelenet
"""

# Load pelenet modules
from pelenet.utils import Utils
from pelenet.experiments.readoutanisotropic import AnisotropicReadoutExperiment

# Official modules
import numpy as np
import matplotlib.pyplot as plt

# %%
# Overwrite default parameters (pelenet/parameters/ and pelenet/experiments/readoutanisotropic.py)
parameters = {
    # Experiment
    'seed': 3,  # Random seed
    'trials': 25,  # Number of trials
    'stepsPerTrial': 110,  # Number of simulation steps for every trial
    'isReset': True,  # Activate reset after every trial
    # Network
    'refractoryDelay': 2, # Refactory period
    'voltageTau': 10.24,  # Voltage time constant
    'currentTau': 10.78,  # Current time constant
    'thresholdMant': 1000,  # Spiking threshold for membrane potential
    'reservoirConnProb': 0.05,
    # Anisotropic
    'anisoStdE': 12,  # Space constant, std of gaussian for excitatory neurons
    'anisoStdI': 9,  # Space constant, std of gaussian for inhibitory neurons (range 9 - 11)
    'anisoShift': 1,  # Intensity of the shift of the connectivity distribution for a neuron
    #'percShift': 1,  # Percentage of shift (default 1)
    'anisoPerlinScale': 4,  # Perlin noise scale, high value => dense valleys, low value => broad valleys
    'weightExCoefficient': 12,  # Coefficient for excitatory anisotropic weight
    'weightInCoefficient': 48,  # Coefficient for inhibitory anisotropic weight
    # Input
    'inputIsTopology': True,
    'inputIsLeaveOut': True,
    'patchNeuronsShiftX': 44,  # x-position of the input area
    'patchNeuronsShiftY': 24,  # y-position of the input area
    'inputNumTargetNeurons': 25,
    'inputSteps': 5,
    'inputWeightExponent': 0,
    'inputGenSpikeProb': 1.0,
    # Output
    'partitioningClusterSize': 10, # size of clusters connected to an output neuron (6|10)
    # Probes
    'isExSpikeProbe': True,  # Probe excitatory spikes
    'isInSpikeProbe': True,   # Probe inhibitory spikes
    'isOutSpikeProbe': True   # Probe output spikes
}

# %%
# Initilizes the experiment, also initializes the log
# Creating a new object results in a new log entry in the 'log' folder
# The name is optional, it is extended to the folder in the log directory
exp = AnisotropicReadoutExperiment(name='anisotropic-network-output-learning', parameters=parameters)

# %%
# Instantiate the utils singleton
utils = Utils.instance()

# %%
# Build the network, in this function the weight matrix, inputs, probes, etc. are defined and created
exp.build()

# %%
# Run the network simulation, afterwards the probes are postprocessed to nice arrays
exp.run()
# Out:
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# INFO:DRV:  Connecting to 127.0.0.1:32977
# INFO:DRV:      Host server up..............Done 0.05s
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/pelenet
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896
# Include dir is : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_0_0.c
# gcc -Wall -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_0_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_spiking_packed.c
# gcc -Wall -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_spiking_packed.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_spiking_packed.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset_init.c
# gcc -Wall -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/2_reset.c
# gcc -Wall -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/2_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/2_reset.c
# /home/seq/pelenet/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/pelenet/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/pelenet/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_0_0.c
# gcc -Wall -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_0_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_0_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_0_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
#
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/pelenet
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896
# Include dir is : /home/seq/pelenet/pelenet/snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_1_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_1_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_1_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_reset_init.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset.c
# /home/seq/pelenet/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/pelenet/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/pelenet/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_1_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_1_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_1_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_1_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_1_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/initnetwork_1_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/0_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/1_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/main_1_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
# INFO:DRV:      Compiling Embedded snips....Done 0.52s
# INFO:DRV:      Encoding axons/synapses.....Done 15.29s
# INFO:DRV:      Encoding probes.............Done 4.74ms
# INFO:HST:  Using Kapoho Bay serial number 308
# INFO:HST:  Args chip=0 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/launcher_chip0_lmt0.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Args chip=1 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1599672400.36896/launcher_chip1_lmt0.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Lakemont_driver...
# INFO:DRV:      Booting up..................Done 1.68s
# INFO:DRV:      Transferring spikes.........Done 0.02s
# INFO:DRV:      Transferring probes.........Done 0.02s
# INFO:DRV:      Configuring registers.......Done 16.57s
# INFO:HST:  chip=1 cpu=0 Transfered values 20, 130, 10
# INFO:HST:  chip=0 cpu=0 Transfered values 20, 130, 10
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 0 to 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 0 to 10
# INFO:HST:  chip=1 cpu=0 Reset functional state at 10
# INFO:HST:  chip=0 cpu=0 Reset functional state at 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 130 to 140
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 130 to 140
# INFO:HST:  chip=0 cpu=0 Reset functional state at 140
# INFO:HST:  chip=1 cpu=0 Reset functional state at 140
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 260 to 270
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 260 to 270
# INFO:HST:  chip=1 cpu=0 Reset functional state at 270
# INFO:HST:  chip=0 cpu=0 Reset functional state at 270
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 390 to 400
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 390 to 400
# INFO:HST:  chip=0 cpu=0 Reset functional state at 400
# INFO:HST:  chip=1 cpu=0 Reset functional state at 400
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 520 to 530
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 520 to 530
# INFO:HST:  chip=1 cpu=0 Reset functional state at 530
# INFO:HST:  chip=0 cpu=0 Reset functional state at 530
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 650 to 660
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 650 to 660
# INFO:HST:  chip=0 cpu=0 Reset functional state at 660
# INFO:HST:  chip=1 cpu=0 Reset functional state at 660
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 780 to 790
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 780 to 790
# INFO:HST:  chip=1 cpu=0 Reset functional state at 790
# INFO:HST:  chip=0 cpu=0 Reset functional state at 790
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 910 to 920
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 910 to 920
# INFO:HST:  chip=0 cpu=0 Reset functional state at 920
# INFO:HST:  chip=1 cpu=0 Reset functional state at 920
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1040 to 1050
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1040 to 1050
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1050
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1050
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1170 to 1180
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1170 to 1180
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1180
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1180
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1300 to 1310
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1300 to 1310
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1310
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1310
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1430 to 1440
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1430 to 1440
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1440
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1440
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1560 to 1570
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1560 to 1570
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1570
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1570
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1690 to 1700
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1690 to 1700
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1700
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1700
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1820 to 1830
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1820 to 1830
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1830
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1830
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1950 to 1960
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1950 to 1960
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1960
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1960
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2080 to 2090
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2080 to 2090
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2090
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2090
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2210 to 2220
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2210 to 2220
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2220
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2220
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2340 to 2350
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2340 to 2350
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2350
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2350
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2470 to 2480
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2470 to 2480
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2480
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2480
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2600 to 2610
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2600 to 2610
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2610
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2610
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2730 to 2740
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2730 to 2740
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2740
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2740
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2860 to 2870
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2860 to 2870
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2870
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2870
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2990 to 3000
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2990 to 3000
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3000
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3000
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 3120 to 3130
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 3120 to 3130
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3130
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3130
# INFO:DRV:      Executing...................Done 255.38s
# INFO:DRV:      Processing timeseries.......Done 1.43s
# INFO:DRV:  Executor: 3250 timesteps........Done 273.44s
# INFO:HST:  chip=0 cpu=0 halted, status=0x0
# INFO:HST:  chip=1 cpu=0 halted, status=0x0

# %%
# Plot spike trains of the excitatory (red) and inhibitory (blue) neurons
exp.net.plot.reservoirSpikeTrain(fr=0, to=450, figsize=(12,6))

# %%
# Plot firing rates of the excitatory (red) and inhibitory (blue) neurons
exp.net.plot.reservoirRates(fr=0, to=450, ylim=(0.0,0.3), figsize=(10,2))

# %%
# Plot spike trains of the pool neurons
exp.net.plot.outputSpikeTrain(fr=0, to=450, color=exp.p.pltColor3, figsize=(12,2))

# %%
# Plot firing rates of the pool neurons
exp.net.plot.outputRates(fr=0, to=450, color=exp.p.pltColor3, ylim=(0,0.5), figsize=(10,2))

# %%
# Get spike data from excitatory neurons and pool neurons
dataEx = exp.net.condenseSpikeProbes(exp.net.exSpikeTrains)
dataOut = exp.net.condenseSpikeProbes(exp.net.outSpikeTrains)

# Fefine target
target = np.sin(np.arange(0,2,0.02))

# %%
# Prepare excitatory spiking data
(x, xe, y) = utils.prepareDataset(dataEx, target, binSize=10)

# %%
# Estimate parameters based all but last trial and predict target based on last trial
# Apply elastic net estimation approach to reduce parameters
predEx = utils.estimateMovement(x, xe, y, alpha=0.001, L1_wt=0.05)

# %%
# Plot target, prediction and smoothed prediction
exp.net.plot.movement1D(predEx, target, legend=True, suffix='reservoir', ylim=(-0.5,1.5), precision=2)

# %%
# Prepare pool spiking data
(x, xe, y) = utils.prepareDataset(dataOut, target, binSize=10)

# %%
# Estimate parameters based all but last trial and predict target based on last trial
predPool = utils.estimateMovement(x, xe, y)

# %%
# Plot target, prediction and smoothed prediction
exp.net.plot.movement1D(predPool, target, legend=True, suffix='pooling', ylim=(-0.5,1.5), precision=2)
