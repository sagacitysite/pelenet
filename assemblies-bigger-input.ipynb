# %%
"""
First insights:

* If an input is trained, it will stay stable, even if it receives less inputs in a second run
* If an input was trained less in a first run, it will strenghten its connections later if its stimuated more often then
* But in this case it will take much more time, since only few spikes are available which takes some time to build up
* If both inputs are trained strongly, further activating patterns have not really any impact anymore
-> An input aquires a specific amount of neurons and stably saturates
-> If it's relatively weak in the beginning it can still become saturates, but then it takes longer

Next steps:
* What happens when the network is bigger?
* What happens when the input it smaller/bigger?
* What happens when a third input comes into play?

"""
# Out:
# "\nFirst insights:\n\n* If an input is trained, it will stay stable, even if it receives less inputs in a second run\n* If an input was trained less in a first run, it will strenghten its connections later if its stimuated more often then\n* But in this case it will take much more time, since only few spikes are available which takes some time to build up\n* If both inputs are trained strongly, further activating patterns have not really any impact anymore\n-> An input aquires a specific amount of neurons and stably saturates\n-> If it's relatively weak in the beginning it can still become saturates, but then it takes longer\n\nNext steps:\n* What happens when the network is bigger?\n* What happens when the input it smaller/bigger?\n* What happens when a third input comes into play?\n\n"

# %%
# Allow reload of objects
# %load_ext autoreload
# %autoreload
from pelenet.utils import Utils
from pelenet.experiments.assemblies import AssemblyExperiment

# Official modules
import numpy as np
import nxsdk.api.n2a as nx
import matplotlib
import matplotlib.pyplot as plt
from time import time
from copy import deepcopy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Overwrite default parameters (pelenet/parameters/ and pelenet/experiments/random.py)
parameters = {
    # Experiment
    'seed': 1,  # Random seed
    'trials': 20,  # Number of trials
    'stepsPerTrial': 50,  # Number of simulation steps for every trial
    'isReset': True,  # Activate reset after every trial
    # Network
    'reservoirExSize': 400,  # Number of excitatory neurons
    'reservoirConnPerNeuron': 35, #35 # Number of connections per neuron
    # Neurons
    'refractoryDelay': 2, # Refactory period
    'voltageTau': 100, #100 # Voltage time constant
    'currentTau': 6, #5 # Current time constant
    'thresholdMant': 1500, #1200  # Spiking threshold for membrane potential
    # Plasticity
    'isLearningRule': True,
    'learningRule': '2^-2*x1*y0 - 2^-2*y1*x0 + 2^-4*x1*y1*y0 - 2^-3*y0*w*w',
    # Input
    'inputIsVary': True,
    'inputVaryProbs': [0.1, 0.9],
    'inputGenSpikeProb': 0.8,  # Probability of spikes for the spike generators
    'inputNumTargetNeurons': 100,  # Number of neurons targeted by the spike generators
    'inputSteps': 30,  # Number of steps the input is active
    # Probes
    'isExSpikeProbe': True,  # Probe excitatory spikes
    'isInSpikeProbe': True,  # Probe inhibitory spikes
    'isWeightProbe': True  # Probe weight matrix at the end of the simulation
}

# %%
# Initilizes the experiment and utils
exp = AssemblyExperiment(name='assemblies', parameters=parameters)
utils = Utils.instance()

# %%
# Build network
exp.build()

# Get spectral radius
utils.getSpectralRadius(exp.net.initialWeights)
# Out:
# 0.922

# %%
# Run network
exp.run()
# Out:
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# INFO:DRV:  Connecting to 127.0.0.1:34875
# INFO:DRV:      Host server up..............Done 0.18s
# INFO:DRV:      Encoding axons/synapses.....Done 0.42s
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/pelenet
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414
# Include dir is : /home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/initnetwork_0_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/initnetwork_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/initnetwork_0_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/0_spiking_packed.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/0_spiking_packed.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/0_spiking_packed.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/1_reset_init.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/1_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/1_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/2_reset.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/2_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/2_reset.c
# /home/seq/pelenet/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/pelenet/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/pelenet/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/main_0_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/main_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/main_0_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/main_0_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/main_0_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
#
# INFO:DRV:      Compiling Embedded snips....Done 0.16s
# INFO:DRV:      Booting up..................Done 0.92s
# INFO:DRV:      Encoding probes.............Done 0.03s
# INFO:DRV:      Transferring probes.........Done 0.08s
# INFO:DRV:      Configuring registers.......Done 0.44s
# INFO:DRV:      Transferring spikes.........Done 0.61s
# INFO:HST:  Using Kapoho Bay serial number 308
# INFO:HST:  Args chip=0 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454009.5259414/launcher_chip0_lmt0.bin --chips=1 --remote-relay=0 --epoch=4
# INFO:HST:  Lakemont_driver...
# INFO:HST:  chip=0 cpu=0 Transfered values 20, 70, 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 0 to 10
# INFO:HST:  chip=0 cpu=0 Reset functional state at 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 70 to 80
# INFO:HST:  chip=0 cpu=0 Reset functional state at 80
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 140 to 150
# INFO:HST:  chip=0 cpu=0 Reset functional state at 150
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 210 to 220
# INFO:HST:  chip=0 cpu=0 Reset functional state at 220
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 280 to 290
# INFO:HST:  chip=0 cpu=0 Reset functional state at 290
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 350 to 360
# INFO:HST:  chip=0 cpu=0 Reset functional state at 360
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 420 to 430
# INFO:HST:  chip=0 cpu=0 Reset functional state at 430
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 490 to 500
# INFO:HST:  chip=0 cpu=0 Reset functional state at 500
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 560 to 570
# INFO:HST:  chip=0 cpu=0 Reset functional state at 570
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 630 to 640
# INFO:HST:  chip=0 cpu=0 Reset functional state at 640
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 700 to 710
# INFO:HST:  chip=0 cpu=0 Reset functional state at 710
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 770 to 780
# INFO:HST:  chip=0 cpu=0 Reset functional state at 780
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 840 to 850
# INFO:HST:  chip=0 cpu=0 Reset functional state at 850
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 910 to 920
# INFO:HST:  chip=0 cpu=0 Reset functional state at 920
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 980 to 990
# INFO:HST:  chip=0 cpu=0 Reset functional state at 990
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1050 to 1060
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1060
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1120 to 1130
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1130
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1190 to 1200
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1200
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1260 to 1270
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1270
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1330 to 1340
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1340
# INFO:DRV:      Executing...................Done 15.80s
# INFO:DRV:      Processing timeseries.......Done 0.40s
# INFO:DRV:  Executor: 1400 timesteps........Done 17.37s
# INFO:HST:  chip=0 cpu=0 halted, status=0x0

# %%
# Plot spike trains of the excitatory (red) and inhibitory (blue) neurons
exp.net.plot.reservoirSpikeTrain(figsize=(12,6))

# %%
# Weight matrix before learning
exp.net.plot.initialExWeightMatrix()

# %%
# Weight matrix after learning
exp.net.plot.trainedExWeightMatrix()

# %%
# Sorted weight matrix after learning
expSupportMask = utils.getSupportWeightsMask(exp.net.trainedWeightsExex)
exp.net.plot.weightsSortedBySupport(expSupportMask)

# %%
# New parameters
newParameters = {
    **parameters,
    'trials': 20,
    'inputVaryProbs': [0.9, 0.1]
}

# %%
# Initilizes a second experiment
exp2 = AssemblyExperiment(name='assemblies-retrain', parameters=newParameters)

# %%
#np.array_equal(exp.initialMasks.exex.toarray(), exp2.initialMasks.exex.toarray())

# %%
# Build network
weights = deepcopy(exp.net.initialWeights)
weights.exex = exp.net.trainedWeightsExex
exp2.buildWithGivenMaskAndWeights(exp.net.initialMasks, weights)

# %%
# Run network
exp2.run()
# Out:
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# INFO:DRV:  Connecting to 127.0.0.1:35529
# INFO:DRV:      Host server up..............Done 0.18s
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/pelenet
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518
# Include dir is : /home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/initnetwork_0_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/initnetwork_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/initnetwork_0_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/0_spiking_packed.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/0_spiking_packed.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/0_spiking_packed.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/1_reset_init.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/1_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/1_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/2_reset.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/2_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/2_reset.c
# /home/seq/pelenet/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/pelenet/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/pelenet/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/main_0_0.c
# gcc -Wall -I/home/seq/pelenet/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/main_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/main_0_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/main_0_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/main_0_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
#
# INFO:DRV:      Compiling Embedded snips....Done 0.17s
# INFO:DRV:      Encoding axons/synapses.....Done 0.32s
# INFO:DRV:      Booting up..................Done 0.85s
# INFO:DRV:      Encoding probes.............Done 0.01s
# INFO:DRV:      Transferring probes.........Done 0.06s
# INFO:DRV:      Configuring registers.......Done 0.43s
# INFO:DRV:      Transferring spikes.........Done 0.61s
# INFO:HST:  Using Kapoho Bay serial number 308
# INFO:HST:  Args chip=0 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1601454036.269518/launcher_chip0_lmt0.bin --chips=1 --remote-relay=0 --epoch=4
# INFO:HST:  Lakemont_driver...
# INFO:HST:  chip=0 cpu=0 Transfered values 20, 70, 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 0 to 10
# INFO:HST:  chip=0 cpu=0 Reset functional state at 10
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 70 to 80
# INFO:HST:  chip=0 cpu=0 Reset functional state at 80
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 140 to 150
# INFO:HST:  chip=0 cpu=0 Reset functional state at 150
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 210 to 220
# INFO:HST:  chip=0 cpu=0 Reset functional state at 220
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 280 to 290
# INFO:HST:  chip=0 cpu=0 Reset functional state at 290
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 350 to 360
# INFO:HST:  chip=0 cpu=0 Reset functional state at 360
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 420 to 430
# INFO:HST:  chip=0 cpu=0 Reset functional state at 430
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 490 to 500
# INFO:HST:  chip=0 cpu=0 Reset functional state at 500
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 560 to 570
# INFO:HST:  chip=0 cpu=0 Reset functional state at 570
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 630 to 640
# INFO:HST:  chip=0 cpu=0 Reset functional state at 640
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 700 to 710
# INFO:HST:  chip=0 cpu=0 Reset functional state at 710
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 770 to 780
# INFO:HST:  chip=0 cpu=0 Reset functional state at 780
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 840 to 850
# INFO:HST:  chip=0 cpu=0 Reset functional state at 850
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 910 to 920
# INFO:HST:  chip=0 cpu=0 Reset functional state at 920
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 980 to 990
# INFO:HST:  chip=0 cpu=0 Reset functional state at 990
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1050 to 1060
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1060
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1120 to 1130
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1130
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1190 to 1200
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1200
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1260 to 1270
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1270
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1330 to 1340
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1340
# INFO:DRV:      Executing...................Done 16.95s
# INFO:DRV:      Processing timeseries.......Done 0.33s
# INFO:DRV:  Executor: 1400 timesteps........Done 18.42s
# INFO:HST:  chip=0 cpu=0 halted, status=0x0

# %%
# Plot spike trains of the excitatory (red) and inhibitory (blue) neurons
exp2.net.plot.reservoirSpikeTrain(figsize=(12,6))

# %%
# Weight matrix before learning
exp2.net.plot.initialExWeightMatrix()

# %%
# Weight matrix after learning
exp2.net.plot.trainedExWeightMatrix()

# %%
# Sorted weight matrix after learning
exp2SupportMask = utils.getSupportWeightsMask(exp2.net.trainedWeightsExex)
exp2.net.plot.weightsSortedBySupport(exp2SupportMask)
