# %%
# Allow reload of objects
# %load_ext autoreload
# %autoreload
from pelenet.utils import Utils
from pelenet.experiments.readoutrandom import ReadoutRandomExperiment

# Official modules
import numpy as np
import nxsdk.api.n2a as nx
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import colors
import os
from time import time

# %%
# Initilizes the experiment and utils
exp = ReadoutRandomExperiment()
utils = Utils.instance()

# %%
# Build network
exp.build()

# Get spectral radius
utils.getSpectralRadius(exp.net.initialWeights)
# Out:
# 1.187

# %%
exp.run()
# Out:
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# WARNING:DRV:  elementType would be deprecated in 0.9 in favor of messageSize, which provides more flexibility
# INFO:DRV:  Connecting to 127.0.0.1:44175
# INFO:DRV:      Host server up..............Done 0.44s
# INFO:DRV:      Encoding axons/synapses.....Done 18.09s
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/05-reward/v0.x
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702
# Include dir is : /home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_0_0.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_0_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_spiking_packed.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_spiking_packed.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_spiking_packed.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset_init.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/2_reset.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/2_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/2_reset.c
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_0_0.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -I/home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/graph/nxinputgen/../../snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_0_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_0_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_0_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_0_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_spiking_packed.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/2_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_0_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
#
# WARNING:DRV:  ~/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages ~/05-reward/v0.x
# Compiling in directory : /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702
# Include dir is : /home/seq/05-reward/v0.x/pelenet/snips/
# Compiling -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_1_0.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_1_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_1_0.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_reset_init.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_reset_init.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_reset_init.c
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset.c
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c: In function ‘reset’:
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c:45:9: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#          nx_fast_init64(nc->cx_state, neuronsPerCore, *(uint64_t*)&cxs);
#          ^~~~~~~~~~~~~~
# /home/seq/05-reward/v0.x/pelenet/snips//reset.c:60:13: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
#              nx_fast_init32(nc->cx_meta_state, neuronsPerCore/4, *(uint32_t*)&ms);
#              ^~~~~~~~~~~~~~
# Compiling without -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_1_0.c
# gcc -Wall -I/home/seq/05-reward/v0.x/pelenet/snips/ -Inxsdk/include -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_1_0.c.o -c /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_1_0.c
# OBJFILES :  /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_1_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_1_0.c.o
# gcc -Wall -fno-stack-protector -msoft-float -m32 -march=i586 -fno-builtin-printf -fno-builtin-sprintf -fno-builtin-fprintf -fno-builtin-memcpy -fstrict-volatile-bitfields -Os -DNDEBUG -std=c99 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/initnetwork_1_0.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/0_reset_init.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/1_reset.c.o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/main_1_0.c.o -o /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/launcher.link nxsdk/lib/embedded/libboot.a nxsdk/lib/embedded/libembedded_nx.a nxsdk/lib/embedded/liblmt.a nxsdk/lib/embedded/libnx.a -Wl,--script=nxsdk/utils/linker.scr -Wl,--build-id=none -Wl,-N -nostdlib
# INFO:DRV:      Compiling Embedded snips....Done 6.01s
# INFO:HST:  Using Kapoho Bay serial number 308
# INFO:HST:  Args chip=0 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/launcher_chip0_lmt0.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Args chip=1 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1593004177.9860702/launcher_chip1_lmt0.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Lakemont_driver...
# INFO:DRV:      Booting up..................Done 1.27s
# INFO:DRV:      Encoding probes.............Done 0.01s
# INFO:DRV:      Configuring registers.......Done 17.61s
# INFO:DRV:      Transferring spikes.........Done 0.05s
# INFO:DRV:      Transferring probes.........Done 0.03s
# INFO:HST:  chip=0 cpu=0 Transfered values 20, 245, 30
# INFO:HST:  chip=1 cpu=0 Transfered values 20, 245, 30
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 0 to 30
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 0 to 30
# INFO:HST:  chip=0 cpu=0 Reset functional state at 30
# INFO:HST:  chip=1 cpu=0 Reset functional state at 30
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 245 to 275
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 245 to 275
# INFO:HST:  chip=0 cpu=0 Reset functional state at 275
# INFO:HST:  chip=1 cpu=0 Reset functional state at 275
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 490 to 520
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 490 to 520
# INFO:HST:  chip=0 cpu=0 Reset functional state at 520
# INFO:HST:  chip=1 cpu=0 Reset functional state at 520
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 735 to 765
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 735 to 765
# INFO:HST:  chip=0 cpu=0 Reset functional state at 765
# INFO:HST:  chip=1 cpu=0 Reset functional state at 765
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 980 to 1010
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 980 to 1010
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1010
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1010
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1225 to 1255
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1225 to 1255
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1255
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1255
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1470 to 1500
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1470 to 1500
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1500
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1500
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1715 to 1745
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1715 to 1745
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1745
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1745
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 1960 to 1990
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 1960 to 1990
# INFO:HST:  chip=0 cpu=0 Reset functional state at 1990
# INFO:HST:  chip=1 cpu=0 Reset functional state at 1990
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2205 to 2235
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2205 to 2235
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2235
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2235
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2450 to 2480
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2450 to 2480
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2480
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2480
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2695 to 2725
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2695 to 2725
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2725
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2725
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 2940 to 2970
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 2940 to 2970
# INFO:HST:  chip=1 cpu=0 Reset functional state at 2970
# INFO:HST:  chip=0 cpu=0 Reset functional state at 2970
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 3185 to 3215
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 3185 to 3215
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3215
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3215
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 3430 to 3460
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 3430 to 3460
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3460
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3460
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 3675 to 3705
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 3675 to 3705
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3705
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3705
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 3920 to 3950
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 3920 to 3950
# INFO:HST:  chip=1 cpu=0 Reset functional state at 3950
# INFO:HST:  chip=0 cpu=0 Reset functional state at 3950
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 4165 to 4195
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 4165 to 4195
# INFO:HST:  chip=0 cpu=0 Reset functional state at 4195
# INFO:HST:  chip=1 cpu=0 Reset functional state at 4195
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 4410 to 4440
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 4410 to 4440
# INFO:HST:  chip=1 cpu=0 Reset functional state at 4440
# INFO:HST:  chip=0 cpu=0 Reset functional state at 4440
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 4655 to 4685
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 4655 to 4685
# INFO:HST:  chip=1 cpu=0 Reset functional state at 4685
# INFO:HST:  chip=0 cpu=0 Reset functional state at 4685
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 4900 to 4930
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 4900 to 4930
# INFO:HST:  chip=0 cpu=0 Reset functional state at 4930
# INFO:HST:  chip=1 cpu=0 Reset functional state at 4930
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 5145 to 5175
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 5145 to 5175
# INFO:HST:  chip=0 cpu=0 Reset functional state at 5175
# INFO:HST:  chip=1 cpu=0 Reset functional state at 5175
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 5390 to 5420
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 5390 to 5420
# INFO:HST:  chip=1 cpu=0 Reset functional state at 5420
# INFO:HST:  chip=0 cpu=0 Reset functional state at 5420
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 5635 to 5665
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 5635 to 5665
# INFO:HST:  chip=1 cpu=0 Reset functional state at 5665
# INFO:HST:  chip=0 cpu=0 Reset functional state at 5665
# INFO:HST:  chip=1 cpu=0 Reset current/voltage from time step 5880 to 5910
# INFO:HST:  chip=0 cpu=0 Reset current/voltage from time step 5880 to 5910
# INFO:HST:  chip=1 cpu=0 Reset functional state at 5910
# INFO:HST:  chip=0 cpu=0 Reset functional state at 5910
# INFO:DRV:      Executing...................Done 418.57s
# INFO:DRV:      Processing timeseries.......Done 2.77s
# INFO:DRV:  Executor: 6125 timesteps........Done 439.05s
# INFO:HST:  chip=0 cpu=0 halted, status=0x0
# INFO:HST:  chip=1 cpu=0 halted, status=0x0

# %%
exp.net.plot.reservoirSpikeTrain(fr=0, to=750, colorEx=exp.p.pltColor4, figsize=(10,6))

# %%
exp.net.plot.reservoirRates(fr=0, to=750, ylim=(0.0,0.3), colorEx=exp.p.pltColor4, figsize=(10,2))

# %%
exp.net.plot.outputSpikeTrain(fr=0, to=500)

# %%
exp.net.plot.outputRates()

# %%
np.save('data/comparison/spikes_ex-random.npy', exp.net.exSpikeData)
np.save('data/comparison/spikes_out-random.npy', exp.net.outSpikeData)

# %%
exp.net.outSpikeData.shape
# Out:
# (25, 200, 210)

# %%
exp.target.shape
# Out:
# (3, 200)

# %%
"""
Generalisation Pool
"""
# Prepare data
(x, xe, y) = utils.prepareDataset(exp.net.outSpikeData, exp.target)

# Estimate and plot x-dim
x1 = utils.estimateMovement(x, xe, y[0])
exp.net.plot.movement1D(x1, exp.target[0], dim='x', ylim=(0.175,0.375), figsize=(6,2))

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(x2, exp.target[1], dim='y', ylim=(0.595,0.655), figsize=(6,2))

# Estimate and plot z-dim
x3 = utils.estimateMovement(x, xe, y[2])
exp.net.plot.movement1D(x3, exp.target[2], dim='z', ylim=(-0.06,0.06), figsize=(6,2))

# Plot 3D
exp.net.plot.movement3D(
    [x1, x2, x3], exp.target, figsize=(10,8),
    xlim=(0.175,0.375), ylim=(0.595,0.655), zlim=(-0.06,0.06)
)

# %%
exp.net.plot.plotDir
# Out:
# '/home/seq/05-reward/v0.x/datalog/2020-06-15_17-43-59/plots/'

# %%
"""
Representation Reservoir
"""
# Prepare data
(x, xe, y) = utils.prepareDataset(exp.net.outSpikeData, exp.target, trainTrials=np.repeat(True, exp.p.trials))

# Estimate and plot x-dim
x1 = utils.estimateMovement(x, xe, y[0])
exp.net.plot.movement1D(x1, exp.target[0], dim='x', ylim=(0.175,0.375), figsize=(6,2))

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(x2, exp.target[1], dim='y', ylim=(0.595,0.655), figsize=(6,2))

# Estimate and plot z-dim
x3 = utils.estimateMovement(x, xe, y[2])
exp.net.plot.movement1D(x3, exp.target[2], dim='z', ylim=(-0.06,0.06), figsize=(6,2))

# Plot 3D
exp.net.plot.movement3D(
    [x1, x2, x3], exp.target, figsize=(10,8),
    xlim=(0.175,0.375), ylim=(0.595,0.655), zlim=(-0.06,0.06)
)

# %%
"""
Representation Reservoir
"""
# Prepare data
(x, xe, y) = utils.prepareDataset(
    exp.net.exSpikeData, exp.target, trainTrials=np.repeat(True, exp.p.trials))

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(
    x2, exp.target[1], dim='y', ylim=(0.62,0.64), figsize=(6,2.5),
    precision=100, suffix='random_representation_reservoir'
)

# %%
"""
Representation Pool
"""
# Prepare data
(x, xe, y) = utils.prepareDataset(
    exp.net.outSpikeData, exp.target, trainTrials=np.repeat(True, exp.p.trials))

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(
    x2, exp.target[1], dim='y', ylim=(0.62,0.64), figsize=(6,2.5),
    precision=100, suffix='random_representation_pool'
)

# %%
"""
Generalisation Reservoir
"""
testTrial = 20

trainTrials=np.repeat(True, exp.p.trials)
trainTrials[testTrial] = False

# Prepare data
(x, xe, y) = utils.prepareDataset(
    exp.net.exSpikeData, exp.target)#, trainTrials=trainTrials, testTrial=testTrial)

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(
    x2, exp.target[1], dim='y', ylim=(0.62,0.64), figsize=(6,2.5),
    precision=100, suffix='random_generalisation_reservoir'
)

# %%
"""
Generalisation Pool
"""

testTrial = 20

trainTrials=np.repeat(True, exp.p.trials)
trainTrials[testTrial] = False

# Prepare data
(x, xe, y) = utils.prepareDataset(
    exp.net.outSpikeData, exp.target)

# Estimate and plot y-dim
x2 = utils.estimateMovement(x, xe, y[1])
exp.net.plot.movement1D(
    x2, exp.target[1], dim='y', ylim=(0.62,0.64), figsize=(6,2.5),
    precision=100, suffix='random_generalisation_pool'
)

# %%
filePath = 'data/robot2/hide_rec_dmp.txt'
targets = np.loadtxt(filePath)

files = [
    'hide_rec_dmp.txt',
    'move_up_rec_dmp.txt',
    'put_on_top_rec_dmp.txt',
    'unhide_rec_dmp.txt',
    'move_down_rec.txt',
    'pick_and_place_rec_dmp.txt',
    'take_down_rec_dmp.txt'
]

targets = np.array([ np.loadtxt('data/robot2/'+file)[-200:,0:3] for file in files ])
targets = np.moveaxis(targets, 1, 2)

# %%
"""
Mutiple targets
"""

# Representation Reservoir
estimatesRepRes = utils.estimateMultipleTrajectories3D(exp.net.exSpikeData, targets, trainTrials=np.repeat(True, exp.p.trials))
# Representation Pool
estimatesRepPoo = utils.estimateMultipleTrajectories3D(exp.net.outSpikeData, targets, trainTrials=np.repeat(True, exp.p.trials))
# Generalisation Reservoir
estimatesGenRes = utils.estimateMultipleTrajectories3D(exp.net.exSpikeData, targets)
# Generalisation Pool
estimatesGenPoo = utils.estimateMultipleTrajectories3D(exp.net.outSpikeData, targets)
# Out:
# 100%|██████████| 7/7 [10:29<00:00, 89.87s/it]
# 100%|██████████| 7/7 [00:01<00:00,  4.30it/s]
# 100%|██████████| 7/7 [09:54<00:00, 84.97s/it]
# 100%|██████████| 7/7 [00:01<00:00,  4.49it/s]

# %%
def calcMSE(estimates):
    mse = []
    for i in range(targets.shape[0]):
        mse.append(np.mean([np.mean(np.square(estimates[i,j] - targets[i,j])) for j in range(3)]))
    return mse

# %%
mse = np.array([
    calcMSE(estimatesRepRes),
    calcMSE(estimatesRepPoo),
    calcMSE(estimatesGenRes),
    calcMSE(estimatesGenPoo)
])

# %%
mseMeans = np.mean(mse, axis=1)

# %%
mseMeans
# Out:
# array([2.06517274e-06, 5.33804504e-03, 9.09230819e+18, 6.48405306e-03])

# %%
#np.save('data/trajectories_randomly.npy', mse)
