# %%
# Allow reload of objects
# %load_ext autoreload
# %autoreload
from system import System
from experiments.static import Experiment

# Official modules
# %matplotlib notebook
import os
import numpy as np
import nxsdk.api.n2a as nx
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import nxsdk.api.n2a as nx

from time import sleep
from time import time
from threading import Thread

# %%
# Initilizes the system
sys = System()

# Initilizes the experiment
inExp = Experiment()

# %%
inExp.build()

# %%
inExp.run()
# Out:
# INFO:DRV:  Connecting to 127.0.0.1:36743
# INFO:DRV:      Host server up..............Done 0.03s
# INFO:DRV:      Compiling Embedded snips....Done 0.12s
# INFO:DRV:      Encoding axons/synapses.....Done 7.15s
# INFO:DRV:      Encoding probes.............Done 0.84s
# INFO:HST:  Using Kapoho Bay serial number 308
# INFO:HST:  Args chip=0 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/compilers/../../../temp/1573478576.9177046/launcher_chip0_lmt0.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Args chip=1 cpu=0 /home/seq/.local/share/virtualenvs/seq-r0_WvjRo/lib/python3.5/site-packages/nxsdk/driver/../bin/x86/kb/init_bs.bin --chips=2 --remote-relay=0 --epoch=0
# INFO:HST:  Lakemont_driver...
# INFO:DRV:      Booting up..................Done 1.47s
# INFO:DRV:      Transferring probes.........Done 0.75s
# INFO:DRV:      Configuring registers.......Done 7.33s
# INFO:DRV:      Transferring spikes.........Done 1.38s
# ...

# %%
inExp.net.exSpikeTrains.shape
# Out:
# (3600, 1000)

# %%
inExp.net.plot.reservoirSpikeTrain()

# %%
inExp.net.plot.reservoirRates()
